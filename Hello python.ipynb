# %% [markdown]
# # Hello friends 👋🏻
# and welcome to the Python course
#
# My name is Hussein Khallouf and i will be your instructor for the course
#
# I hope you get as much as you can from this course.
#
# so get ready...

# %% [markdown]
# ![coding.jpg](attachment:coding.jpg)

# %% [markdown]
# ## Why should i learn programing?

# %% [markdown]
# ### 1. It Guarantees You a Job
#  We’re living in the era of technology, and technological growth is nowhere near stopping. As the use of technological devices is growing every year, there will always be a high demand for programmers.
#
# ### 2. No Need for a Five-Year Degree
# While one of the paths to becoming a programmer is to earn a computer science degree, you can still become one without a degree
#
# ### 3. You Get to Work From Home
# Since the job only requires a computer with an internet connection, employees often have the opportunity to work remotely.
#
# ### 4. You Can Create Anything You Want
# Computer programming, like no other job, gives you the opportunity to digitize your ideas. This idea can include an app you wanted to create and thought that would go viral once you put in the market. However, creating an app, it’s not an easy task as it requires effort, time, and money.
#
# ### 5. You Understand How Software Works
# Programming will get you familiar with the software, programs, devices, and websites and will help you understand them.
#
# ### 6. You Learn To Combine Technical Skills and Creativity
#  Not all industries will give you the opportunity to use both your technical and creative skills as programming will. This is possible due to the nature of the job. It focuses on identifying issues and resolving them.

# %% [markdown]
# ## Why Python?
# Python is a powerful general-purpose programming language. It is used in **web development**, **data science**, **creating software prototypes**, **AI applications(ML, DL, CV)** and so on. Fortunately for beginners, Python has simple easy-to-use syntax. This makes Python an excellent language to learn to program for beginners.

# %% [markdown]
# ### What Python does well
# * #### Python is easy to use
# It isn’t unusual for coding an
# application in Python to take one-fifth the time it would in C or Java and to take as little
# as one-fifth the number of lines of the equivalent C program.
# * #### Python is expressive
# a single line of Python code can do more than a single line of code in most other languages.
# * #### Python is readable
# You might think that a programming language needs to be read only by a computer, but humans have to read your code
# as well
# * #### Python is complete “batteries included”
# “batteries included” philosophy when it comes to libraries. The idea is that when you install Python, you should have everything you need to do real work without the need to install additional libraries.
# * #### Python is cross-platform
# Python runs on many platforms:Windows, Mac, Linux, UNIX, and so on.
# * #### Python is free
# It’s freely available. You can download and install practically any version of Python and use it to develop software for commercial or personal applications, and you don’t need to pay a dime.

# %% [markdown]
# ### What Python doesn’t do as well
# Although Python has many advantages, no language can do everything, so Python
# isn’t the perfect solution for all your needs. To decide whether Python is the right language
# for your situation, you also need to consider the areas where Python doesn’t do
# as well.

# %% [markdown]
# * #### Python isn’t the fastest language
# Python isn’t the fastest language, using Python results in slower programs than in a language like C. But you should
# keep this in perspective.
# * #### Python doesn’t have much mobile support
# Python isn’t a strong player in this space. While options exist, running Python on mobile devices isn’t always easy.
# * #### Python doesn’t use multiple processors well
# the standard implementation of Python isn’t designed to use multiple cores.

# %% [markdown]
# #### Why learn Python 3?
# Python has been around for a number of years and has evolved over that time.<br>
# <a href='https://www.python.org/downloads/'> download python</a>
# #### <a href='https://docs.python.org/3/'>python documentation</a>

# %% [markdown]
# ### Where do you write Python code?
# We can use any text editing software to write a Python script file.
# We just need to save it with the `.py`
# ####  Integrated Development Environment (IDE)
# IDE is a piece of software that provides useful features like code hinting, syntax highlighting and checking, file explorers, etc. to the programmer for application development, So using an IDE can make our life a lot easier.
# for example <a href='https://www.jetbrains.com/pycharm/'>PyCharm</a>
# #### perfect source code editor
# ##### Visual Studio Code
#  is a lightweight but powerful source code editor which runs on your desktop and is available for Windows, macOS and Linux. It comes with built-in support for JavaScript, C++, C#, Java, Python and other languages
# <a href='https://code.visualstudio.com/'>VScode</a>

# %% [markdown]
# ### Hello World!

# %%
print('Hello World!')
# Out:
# Hello World!
